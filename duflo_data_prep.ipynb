# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import random

# %matplotlib inline

# %%
# village_files = os.listdir('/Users/Adam/Desktop/Code Projects/randomized_network_recruitment/duflo_data/Data/1. Network Data/Adjacency Matrices/')
# key_files = os.listdir('/Users/Adam/Desktop/Code Projects/randomized_network_recruitment/duflo_data/Data/1. Network Data/Adjacency Matrix Keys/')

# for k, w in zip(village_files, key_files):
    
#     df = pd.read_csv('/Users/Adam/Desktop/Code Projects/randomized_network_recruitment/duflo_data/Data/1. Network Data/Adjacency Matrices/' + i, header = None)
#     key_df = pd.read_csv('/Users/Adam/Desktop/Code Projects/randomized_network_recruitment/duflo_data/Data/1. Network Data/Adjacency Matrix Keys/' + j, header = None)
#     key = key_df[0].tolist()

#     #reformat and create graph

#     df.columns = key
#     df.set_index(pd.Series(key), inplace=True)

#     G = nx.from_pandas_adjacency(df)

# %%
#import adjacency matrix as df and associated key as key

df = pd.read_csv('/Users/Adam/Desktop/Code Projects/randomized_network_recruitment/duflo_data/Data/1. Network Data/Adjacency Matrices/adj_allVillageRelationships_HH_vilno_1.csv', header = None)
key_df = pd.read_csv('/Users/Adam/Desktop/Code Projects/randomized_network_recruitment/duflo_data/Data/1. Network Data/Adjacency Matrix Keys/key_HH_vilno_1.csv', header = None)
key = key_df[0].tolist()

#reformat and greate graph

df.columns = key
df.set_index(pd.Series(key), inplace=True)

H = nx.from_pandas_adjacency(df)

# %%
random.seed(1)
plt.figure(3,figsize=(12,12)) 
nx.draw_spring(H,node_size=25)
# Out:
# C:\Users\Adam\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
